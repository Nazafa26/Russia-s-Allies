# %% [markdown]
# ## Who are Russia’s supporters?

# %% [markdown]
# The following python code and data visualization is based on the article was published in the Economist on March 31st 2023 under the same title "Who are Russia's supporters?".
#
# According to this article, the number of countries openly criticizing Russia has decreased compared to the previous year. But this article claims these countries that have toned down their condemnation are not of much practical use to Vladimir Putin, Russia President, and his aggressive actions.
#
# In this python project, the data was obtained from the Economist data source and we cleaned and used them to show the dependency and relations of Russia and its supporter countries in graph.
#
# This project doesn't contain all the data regarding the countries and their cooperations with Moscow.

# %% [markdown]
# ## Aim

# %% [markdown]
# In this project, we show how to clean data and do visualization in Jupyter note book. Matplotlib and Seaborn are python libraries that are used for data visualization. They have inbuilt modules for plotting different graphs.
# While Tableau has a full capacity for the graphs and data visualization, but you can also use python libraries in some extended capacity.
# While Matplotlib is used to embed graphs into applications, Seaborn is primarily used for statistical graphs.

# %% [markdown]
# ## Data

# %% [markdown]
# ##### You can find the data source and article from the following link and create your own project:

# %% [markdown]
# https://www.economist.com/graphic-detail/2023/03/31/who-are-russias-supporters

# %% [markdown]
# ### Libraries Used

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas

# %%
df = pd.read_csv('PutinsPals.csv')

# %%
df.head(15)
# Out:
#     Unnamed: 0                        Unnamed: 1  \
# 0      Country  UN: did not vote against Russia
# 1      Belarus                              TRUE
# 2      Armenia                              TRUE
# 3   Kyrgyzstan                              TRUE
# 4         Iran                              TRUE
# 5   Tajikistan                              TRUE
# 6   Kazakhstan                              TRUE
# 7       Syria                               TRUE
# 8        China                              TRUE
# 9    Venezuela                              TRUE
# 10   Nicaragua                              TRUE
# 11       India                              TRUE
# 12  Uzbekistan                              TRUE
# 13         NaN                               NaN
# 14      Notes:                               NaN
#
#                           Unnamed: 2  \
# 0   Voted with Russia at least twice
# 1                               TRUE
# 2                              FALSE
# 3                              FALSE
# 4                              FALSE
# 5                              FALSE
# 6                              FALSE
# 7                               TRUE
# 8                              FALSE
# 9                              FALSE
# 10                              TRUE
# 11                             FALSE
# 12                             FALSE
# 13                               NaN
# 14                               NaN
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 13                                                NaN          NaN
# 14                                                NaN          NaN
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 13                                 NaN
# 14                                 NaN
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 13                                        NaN             NaN
# 14                                        NaN             NaN
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 13                NaN            NaN                               NaN
# 14                NaN            NaN                               NaN
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 13                                             NaN          NaN
# 14                                             NaN          NaN

# %%
# Fill NAs with 0s
df = df.fillna(0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 13                                                  0
# 14                                             Notes:
# 15  Votes in the UN General Assembly considers sev...
# 16  Supplying arms: Whether a country has reported...
# 17  Considered arms dependent if more than 50% of ...
# 18  Considered nuclear dependent if listed as high...
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 13                                 0                                 0
# 14                                 0                                 0
# 15                                 0                                 0
# 16                                 0                                 0
# 17                                 0                                 0
# 18                                 0                                 0
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 13                                                  0            0
# 14                                                  0            0
# 15                                                  0            0
# 16                                                  0            0
# 17                                                  0            0
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 13                                   0
# 14                                   0
# 15                                   0
# 16                                   0
# 17                                   0
# 18                                   0
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 13                                          0               0
# 14                                          0               0
# 15                                          0               0
# 16                                          0               0
# 17                                          0               0
# 18                                          0               0
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 13                  0              0                                 0
# 14                  0              0                                 0
# 15                  0              0                                 0
# 16                  0              0                                 0
# 17                  0              0                                 0
# 18                  0              0                                 0
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 13                                               0            0
# 14                                               0            0
# 15                                               0            0
# 16                                               0            0
# 17                                               0            0
# 18                                               0            0
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13])

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 14                                             Notes:
# 15  Votes in the UN General Assembly considers sev...
# 16  Supplying arms: Whether a country has reported...
# 17  Considered arms dependent if more than 50% of ...
# 18  Considered nuclear dependent if listed as high...
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 14                                 0                                 0
# 15                                 0                                 0
# 16                                 0                                 0
# 17                                 0                                 0
# 18                                 0                                 0
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 14                                                  0            0
# 15                                                  0            0
# 16                                                  0            0
# 17                                                  0            0
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 14                                   0
# 15                                   0
# 16                                   0
# 17                                   0
# 18                                   0
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 14                                          0               0
# 15                                          0               0
# 16                                          0               0
# 17                                          0               0
# 18                                          0               0
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 14                  0              0                                 0
# 15                  0              0                                 0
# 16                  0              0                                 0
# 17                  0              0                                 0
# 18                  0              0                                 0
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 14                                               0            0
# 15                                               0            0
# 16                                               0            0
# 17                                               0            0
# 18                                               0            0
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[14], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 14                                             Notes:
# 16  Supplying arms: Whether a country has reported...
# 17  Considered arms dependent if more than 50% of ...
# 18  Considered nuclear dependent if listed as high...
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 14                                 0                                 0
# 16                                 0                                 0
# 17                                 0                                 0
# 18                                 0                                 0
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 14                                                  0            0
# 16                                                  0            0
# 17                                                  0            0
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 14                                   0
# 16                                   0
# 17                                   0
# 18                                   0
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 14                                          0               0
# 16                                          0               0
# 17                                          0               0
# 18                                          0               0
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 14                  0              0                                 0
# 16                  0              0                                 0
# 17                  0              0                                 0
# 18                  0              0                                 0
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 14                                               0            0
# 16                                               0            0
# 17                                               0            0
# 18                                               0            0
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 16  Supplying arms: Whether a country has reported...
# 17  Considered arms dependent if more than 50% of ...
# 18  Considered nuclear dependent if listed as high...
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 16                                 0                                 0
# 17                                 0                                 0
# 18                                 0                                 0
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 16                                                  0            0
# 17                                                  0            0
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 16                                   0
# 17                                   0
# 18                                   0
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 16                                          0               0
# 17                                          0               0
# 18                                          0               0
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 16                  0              0                                 0
# 17                  0              0                                 0
# 18                  0              0                                 0
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 16                                               0            0
# 17                                               0            0
# 18                                               0            0
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 17  Considered arms dependent if more than 50% of ...
# 18  Considered nuclear dependent if listed as high...
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 17                                 0                                 0
# 18                                 0                                 0
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 17                                                  0            0
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 17                                   0
# 18                                   0
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 17                                          0               0
# 18                                          0               0
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 17                  0              0                                 0
# 18                  0              0                                 0
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 17                                               0            0
# 18                                               0            0
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 18  Considered nuclear dependent if listed as high...
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 18                                 0                                 0
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 18                                                  0            0
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 18                                   0
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 18                                          0               0
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 18                  0              0                                 0
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 18                                               0            0
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 19  Gas dependent if gets 50% or more of natural g...
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 19                                 0                                 0
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 19                                                  0            0
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 19                                   0
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 19                                          0               0
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 19                  0              0                                 0
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 19                                               0            0
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 20  Increased exports if average monthly goods exp...
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 20                                 0                                 0
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 20                                                  0            0
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 20                                   0
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 20                                          0               0
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 20                  0              0                                 0
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 20                                               0            0
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0  \
# 0                                             Country
# 1                                             Belarus
# 2                                             Armenia
# 3                                          Kyrgyzstan
# 4                                                Iran
# 5                                          Tajikistan
# 6                                          Kazakhstan
# 7                                              Syria
# 8                                               China
# 9                                           Venezuela
# 10                                          Nicaragua
# 11                                              India
# 12                                         Uzbekistan
# 21  CSTO is the Collective Security Treaty Organiz...
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...
#
#                           Unnamed: 1                        Unnamed: 2  \
# 0   UN: did not vote against Russia   Voted with Russia at least twice
# 1                               TRUE                              TRUE
# 2                               TRUE                             FALSE
# 3                               TRUE                             FALSE
# 4                               TRUE                             FALSE
# 5                               TRUE                             FALSE
# 6                               TRUE                             FALSE
# 7                               TRUE                              TRUE
# 8                               TRUE                             FALSE
# 9                               TRUE                             FALSE
# 10                              TRUE                              TRUE
# 11                              TRUE                             FALSE
# 12                              TRUE                             FALSE
# 21                                 0                                 0
# 22                                 0                                 0
#
#                                            Unnamed: 3   Unnamed: 4  \
# 0   Supplying arms to Russia since the start of th...  CSTO member
# 1                                                TRUE         TRUE
# 2                                               FALSE         TRUE
# 3                                               FALSE         TRUE
# 4                                                TRUE        FALSE
# 5                                               FALSE         TRUE
# 6                                               FALSE         TRUE
# 7                                               FALSE        FALSE
# 8                                               FALSE        FALSE
# 9                                               FALSE        FALSE
# 10                                              FALSE        FALSE
# 11                                              FALSE        FALSE
# 12                                              FALSE        FALSE
# 21                                                  0            0
# 22                                                  0            0
#
#                             Unnamed: 5  \
# 0   Russian troops mercenaries present
# 1                                 TRUE
# 2                                 TRUE
# 3                                 TRUE
# 4                                FALSE
# 5                                 TRUE
# 6                                FALSE
# 7                                 TRUE
# 8                                FALSE
# 9                                 TRUE
# 10                               FALSE
# 11                               FALSE
# 12                               FALSE
# 21                                   0
# 22                                   0
#
#                                    Unnamed: 6      Unnamed: 7  \
# 0   Held joint military drills since Feb 2022  Arms dependent
# 1                                        TRUE            TRUE
# 2                                        TRUE            TRUE
# 3                                        TRUE            TRUE
# 4                                        TRUE            TRUE
# 5                                        TRUE            TRUE
# 6                                        TRUE            TRUE
# 7                                        TRUE            TRUE
# 8                                        TRUE            TRUE
# 9                                        TRUE            TRUE
# 10                                       TRUE            TRUE
# 11                                       TRUE            TRUE
# 12                                      FALSE           FALSE
# 21                                          0               0
# 22                                          0               0
#
#            Unnamed: 8     Unnamed: 9                       Unnamed: 10  \
# 0   Nuclear dependent  Gas dependent  Increased exports since Feb 2022
# 1                TRUE           TRUE                              TRUE
# 2                TRUE           TRUE                              TRUE
# 3               FALSE           TRUE                              TRUE
# 4                TRUE          FALSE                              TRUE
# 5               FALSE          FALSE                             FALSE
# 6               FALSE          FALSE                              TRUE
# 7               FALSE          FALSE                             FALSE
# 8                TRUE          FALSE                              TRUE
# 9               FALSE          FALSE                              TRUE
# 10              FALSE          FALSE                             FALSE
# 11               TRUE          FALSE                             FALSE
# 12               TRUE          FALSE                              TRUE
# 21                  0              0                                 0
# 22                  0              0                                 0
#
#                                        Unnamed: 11  Unnamed: 12
# 0   More than 10% of total goods trade with Russia  Total score
# 1                                             TRUE           11
# 2                                             TRUE            9
# 3                                             TRUE            8
# 4                                            FALSE            6
# 5                                             TRUE            6
# 6                                             TRUE            6
# 7                                            FALSE            5
# 8                                            FALSE            5
# 9                                            FALSE            5
# 10                                           FALSE            4
# 11                                           FALSE            4
# 12                                            TRUE            4
# 21                                               0            0
# 22                                               0            0

# %%
df = df.drop(df.index[0], axis=0)

# %%
df
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 1                                             Belarus       TRUE       TRUE
# 2                                             Armenia       TRUE      FALSE
# 3                                          Kyrgyzstan       TRUE      FALSE
# 4                                                Iran       TRUE      FALSE
# 5                                          Tajikistan       TRUE      FALSE
# 6                                          Kazakhstan       TRUE      FALSE
# 7                                              Syria        TRUE       TRUE
# 8                                               China       TRUE      FALSE
# 9                                           Venezuela       TRUE      FALSE
# 10                                          Nicaragua       TRUE       TRUE
# 11                                              India       TRUE      FALSE
# 12                                         Uzbekistan       TRUE      FALSE
# 21  CSTO is the Collective Security Treaty Organiz...          0          0
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...          0          0
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 1        TRUE       TRUE       TRUE       TRUE       TRUE       TRUE
# 2       FALSE       TRUE       TRUE       TRUE       TRUE       TRUE
# 3       FALSE       TRUE       TRUE       TRUE       TRUE      FALSE
# 4        TRUE      FALSE      FALSE       TRUE       TRUE       TRUE
# 5       FALSE       TRUE       TRUE       TRUE       TRUE      FALSE
# 6       FALSE       TRUE      FALSE       TRUE       TRUE      FALSE
# 7       FALSE      FALSE       TRUE       TRUE       TRUE      FALSE
# 8       FALSE      FALSE      FALSE       TRUE       TRUE       TRUE
# 9       FALSE      FALSE       TRUE       TRUE       TRUE      FALSE
# 10      FALSE      FALSE      FALSE       TRUE       TRUE      FALSE
# 11      FALSE      FALSE      FALSE       TRUE       TRUE       TRUE
# 12      FALSE      FALSE      FALSE      FALSE      FALSE       TRUE
# 21          0          0          0          0          0          0
# 22          0          0          0          0          0          0
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 1        TRUE        TRUE        TRUE          11
# 2        TRUE        TRUE        TRUE           9
# 3        TRUE        TRUE        TRUE           8
# 4       FALSE        TRUE       FALSE           6
# 5       FALSE       FALSE        TRUE           6
# 6       FALSE        TRUE        TRUE           6
# 7       FALSE       FALSE       FALSE           5
# 8       FALSE        TRUE       FALSE           5
# 9       FALSE        TRUE       FALSE           5
# 10      FALSE       FALSE       FALSE           4
# 11      FALSE       FALSE       FALSE           4
# 12      FALSE        TRUE        TRUE           4
# 21          0           0           0           0
# 22          0           0           0           0

# %%
df.groupby(['Unnamed: 0'])['Unnamed: 3'].sum()
# Out:
# Unnamed: 0
# Armenia                                                                                                                                              FALSE
# Belarus                                                                                                                                               TRUE
# CSTO is the Collective Security Treaty Organization (CSTO), a mutual defence pact                                                                        0
# China                                                                                                                                                FALSE
# India                                                                                                                                                FALSE
# Iran                                                                                                                                                  TRUE
# Kazakhstan                                                                                                                                           FALSE
# Kyrgyzstan                                                                                                                                           FALSE
# Nicaragua                                                                                                                                            FALSE
# Sources: The Economist; IEA; IMF; IISS; Silverado Policy Accelerator; Global Trade Tracker; UN Comtrade; CEIC Data; national statistics databases        0
# Syria                                                                                                                                                FALSE
# Tajikistan                                                                                                                                           FALSE
# Uzbekistan                                                                                                                                           FALSE
# Venezuela                                                                                                                                            FALSE
# Name: Unnamed: 3, dtype: object

# %%
column_name = 'Unnamed: 0'  # Replace 'column_name' with the actual column name



# Rename the column (optional)
df = df.rename(columns={column_name: 'Countries'})  # Replace 'new_column_name' with the desired new name

# %%
df
# Out:
#                                             Countries Unnamed: 1 Unnamed: 2  \
# 1                                             Belarus       TRUE       TRUE
# 2                                             Armenia       TRUE      FALSE
# 3                                          Kyrgyzstan       TRUE      FALSE
# 4                                                Iran       TRUE      FALSE
# 5                                          Tajikistan       TRUE      FALSE
# 6                                          Kazakhstan       TRUE      FALSE
# 7                                              Syria        TRUE       TRUE
# 8                                               China       TRUE      FALSE
# 9                                           Venezuela       TRUE      FALSE
# 10                                          Nicaragua       TRUE       TRUE
# 11                                              India       TRUE      FALSE
# 12                                         Uzbekistan       TRUE      FALSE
# 21  CSTO is the Collective Security Treaty Organiz...          0          0
# 22  Sources: The Economist; IEA; IMF; IISS; Silver...          0          0
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 1        TRUE       TRUE       TRUE       TRUE       TRUE       TRUE
# 2       FALSE       TRUE       TRUE       TRUE       TRUE       TRUE
# 3       FALSE       TRUE       TRUE       TRUE       TRUE      FALSE
# 4        TRUE      FALSE      FALSE       TRUE       TRUE       TRUE
# 5       FALSE       TRUE       TRUE       TRUE       TRUE      FALSE
# 6       FALSE       TRUE      FALSE       TRUE       TRUE      FALSE
# 7       FALSE      FALSE       TRUE       TRUE       TRUE      FALSE
# 8       FALSE      FALSE      FALSE       TRUE       TRUE       TRUE
# 9       FALSE      FALSE       TRUE       TRUE       TRUE      FALSE
# 10      FALSE      FALSE      FALSE       TRUE       TRUE      FALSE
# 11      FALSE      FALSE      FALSE       TRUE       TRUE       TRUE
# 12      FALSE      FALSE      FALSE      FALSE      FALSE       TRUE
# 21          0          0          0          0          0          0
# 22          0          0          0          0          0          0
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 1        TRUE        TRUE        TRUE          11
# 2        TRUE        TRUE        TRUE           9
# 3        TRUE        TRUE        TRUE           8
# 4       FALSE        TRUE       FALSE           6
# 5       FALSE       FALSE        TRUE           6
# 6       FALSE        TRUE        TRUE           6
# 7       FALSE       FALSE       FALSE           5
# 8       FALSE        TRUE       FALSE           5
# 9       FALSE        TRUE       FALSE           5
# 10      FALSE       FALSE       FALSE           4
# 11      FALSE       FALSE       FALSE           4
# 12      FALSE        TRUE        TRUE           4
# 21          0           0           0           0
# 22          0           0           0           0

# %%
df = df.drop(df.index[13], axis=0)

# %%
df
# Out:
#                                             Countries Unnamed: 1 Unnamed: 2  \
# 1                                             Belarus       TRUE       TRUE
# 2                                             Armenia       TRUE      FALSE
# 3                                          Kyrgyzstan       TRUE      FALSE
# 4                                                Iran       TRUE      FALSE
# 5                                          Tajikistan       TRUE      FALSE
# 6                                          Kazakhstan       TRUE      FALSE
# 7                                              Syria        TRUE       TRUE
# 8                                               China       TRUE      FALSE
# 9                                           Venezuela       TRUE      FALSE
# 10                                          Nicaragua       TRUE       TRUE
# 11                                              India       TRUE      FALSE
# 12                                         Uzbekistan       TRUE      FALSE
# 21  CSTO is the Collective Security Treaty Organiz...          0          0
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 1        TRUE       TRUE       TRUE       TRUE       TRUE       TRUE
# 2       FALSE       TRUE       TRUE       TRUE       TRUE       TRUE
# 3       FALSE       TRUE       TRUE       TRUE       TRUE      FALSE
# 4        TRUE      FALSE      FALSE       TRUE       TRUE       TRUE
# 5       FALSE       TRUE       TRUE       TRUE       TRUE      FALSE
# 6       FALSE       TRUE      FALSE       TRUE       TRUE      FALSE
# 7       FALSE      FALSE       TRUE       TRUE       TRUE      FALSE
# 8       FALSE      FALSE      FALSE       TRUE       TRUE       TRUE
# 9       FALSE      FALSE       TRUE       TRUE       TRUE      FALSE
# 10      FALSE      FALSE      FALSE       TRUE       TRUE      FALSE
# 11      FALSE      FALSE      FALSE       TRUE       TRUE       TRUE
# 12      FALSE      FALSE      FALSE      FALSE      FALSE       TRUE
# 21          0          0          0          0          0          0
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 1        TRUE        TRUE        TRUE          11
# 2        TRUE        TRUE        TRUE           9
# 3        TRUE        TRUE        TRUE           8
# 4       FALSE        TRUE       FALSE           6
# 5       FALSE       FALSE        TRUE           6
# 6       FALSE        TRUE        TRUE           6
# 7       FALSE       FALSE       FALSE           5
# 8       FALSE        TRUE       FALSE           5
# 9       FALSE        TRUE       FALSE           5
# 10      FALSE       FALSE       FALSE           4
# 11      FALSE       FALSE       FALSE           4
# 12      FALSE        TRUE        TRUE           4
# 21          0           0           0           0

# %%
df = df.drop(df.index[12], axis=0)

# %%
df
# Out:
#      Countries Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1      Belarus       TRUE       TRUE       TRUE       TRUE       TRUE
# 2      Armenia       TRUE      FALSE      FALSE       TRUE       TRUE
# 3   Kyrgyzstan       TRUE      FALSE      FALSE       TRUE       TRUE
# 4         Iran       TRUE      FALSE       TRUE      FALSE      FALSE
# 5   Tajikistan       TRUE      FALSE      FALSE       TRUE       TRUE
# 6   Kazakhstan       TRUE      FALSE      FALSE       TRUE      FALSE
# 7       Syria        TRUE       TRUE      FALSE      FALSE       TRUE
# 8        China       TRUE      FALSE      FALSE      FALSE      FALSE
# 9    Venezuela       TRUE      FALSE      FALSE      FALSE       TRUE
# 10   Nicaragua       TRUE       TRUE      FALSE      FALSE      FALSE
# 11       India       TRUE      FALSE      FALSE      FALSE      FALSE
# 12  Uzbekistan       TRUE      FALSE      FALSE      FALSE      FALSE
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 1        TRUE       TRUE       TRUE       TRUE        TRUE        TRUE
# 2        TRUE       TRUE       TRUE       TRUE        TRUE        TRUE
# 3        TRUE       TRUE      FALSE       TRUE        TRUE        TRUE
# 4        TRUE       TRUE       TRUE      FALSE        TRUE       FALSE
# 5        TRUE       TRUE      FALSE      FALSE       FALSE        TRUE
# 6        TRUE       TRUE      FALSE      FALSE        TRUE        TRUE
# 7        TRUE       TRUE      FALSE      FALSE       FALSE       FALSE
# 8        TRUE       TRUE       TRUE      FALSE        TRUE       FALSE
# 9        TRUE       TRUE      FALSE      FALSE        TRUE       FALSE
# 10       TRUE       TRUE      FALSE      FALSE       FALSE       FALSE
# 11       TRUE       TRUE       TRUE      FALSE       FALSE       FALSE
# 12      FALSE      FALSE       TRUE      FALSE        TRUE        TRUE
#
#    Unnamed: 12
# 1           11
# 2            9
# 3            8
# 4            6
# 5            6
# 6            6
# 7            5
# 8            5
# 9            5
# 10           4
# 11           4
# 12           4

# %%
column_name = 'Unnamed: 1'  # Replace 'column_name' with the actual column name



# Rename the column (optional)
df = df.rename(columns={column_name: 'Not vote against Russia'})  # Replace 'new_column_name' with the desired new name

# %%
df
# Out:
#      Countries Not vote against Russia Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 1      Belarus                    TRUE       TRUE       TRUE       TRUE
# 2      Armenia                    TRUE      FALSE      FALSE       TRUE
# 3   Kyrgyzstan                    TRUE      FALSE      FALSE       TRUE
# 4         Iran                    TRUE      FALSE       TRUE      FALSE
# 5   Tajikistan                    TRUE      FALSE      FALSE       TRUE
# 6   Kazakhstan                    TRUE      FALSE      FALSE       TRUE
# 7       Syria                     TRUE       TRUE      FALSE      FALSE
# 8        China                    TRUE      FALSE      FALSE      FALSE
# 9    Venezuela                    TRUE      FALSE      FALSE      FALSE
# 10   Nicaragua                    TRUE       TRUE      FALSE      FALSE
# 11       India                    TRUE      FALSE      FALSE      FALSE
# 12  Uzbekistan                    TRUE      FALSE      FALSE      FALSE
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 1        TRUE       TRUE       TRUE       TRUE       TRUE        TRUE
# 2        TRUE       TRUE       TRUE       TRUE       TRUE        TRUE
# 3        TRUE       TRUE       TRUE      FALSE       TRUE        TRUE
# 4       FALSE       TRUE       TRUE       TRUE      FALSE        TRUE
# 5        TRUE       TRUE       TRUE      FALSE      FALSE       FALSE
# 6       FALSE       TRUE       TRUE      FALSE      FALSE        TRUE
# 7        TRUE       TRUE       TRUE      FALSE      FALSE       FALSE
# 8       FALSE       TRUE       TRUE       TRUE      FALSE        TRUE
# 9        TRUE       TRUE       TRUE      FALSE      FALSE        TRUE
# 10      FALSE       TRUE       TRUE      FALSE      FALSE       FALSE
# 11      FALSE       TRUE       TRUE       TRUE      FALSE       FALSE
# 12      FALSE      FALSE      FALSE       TRUE      FALSE        TRUE
#
#    Unnamed: 11 Unnamed: 12
# 1         TRUE          11
# 2         TRUE           9
# 3         TRUE           8
# 4        FALSE           6
# 5         TRUE           6
# 6         TRUE           6
# 7        FALSE           5
# 8        FALSE           5
# 9        FALSE           5
# 10       FALSE           4
# 11       FALSE           4
# 12        TRUE           4

# %%
column_names_mapping = {
    'Unnamed: 2': 'Voted for Russia',
    'Unnamed: 3': 'Arms Supplier',
    'Unnamed: 4': 'CSTO member',
    'Unnamed: 6': 'Joint military drills',
    'Unnamed: 7': 'Arms dependent',
    'Unnamed: 8': 'Nuclear dependent',
    'Unnamed: 9': 'Gas dependent',
    'Unnamed: 10': 'Increased exports',
    'Unnamed: 11': 'At least 10% trade'
    
}

# Rename the columns
df = df.rename(columns=column_names_mapping)

# %%
df
# Out:
#      Countries Not vote against Russia Voted for Russia Arms Supplier  \
# 1      Belarus                    TRUE             TRUE          TRUE
# 2      Armenia                    TRUE            FALSE         FALSE
# 3   Kyrgyzstan                    TRUE            FALSE         FALSE
# 4         Iran                    TRUE            FALSE          TRUE
# 5   Tajikistan                    TRUE            FALSE         FALSE
# 6   Kazakhstan                    TRUE            FALSE         FALSE
# 7       Syria                     TRUE             TRUE         FALSE
# 8        China                    TRUE            FALSE         FALSE
# 9    Venezuela                    TRUE            FALSE         FALSE
# 10   Nicaragua                    TRUE             TRUE         FALSE
# 11       India                    TRUE            FALSE         FALSE
# 12  Uzbekistan                    TRUE            FALSE         FALSE
#
#    CSTO member Unnamed: 5 Joint military drills Arms dependent  \
# 1         TRUE       TRUE                  TRUE           TRUE
# 2         TRUE       TRUE                  TRUE           TRUE
# 3         TRUE       TRUE                  TRUE           TRUE
# 4        FALSE      FALSE                  TRUE           TRUE
# 5         TRUE       TRUE                  TRUE           TRUE
# 6         TRUE      FALSE                  TRUE           TRUE
# 7        FALSE       TRUE                  TRUE           TRUE
# 8        FALSE      FALSE                  TRUE           TRUE
# 9        FALSE       TRUE                  TRUE           TRUE
# 10       FALSE      FALSE                  TRUE           TRUE
# 11       FALSE      FALSE                  TRUE           TRUE
# 12       FALSE      FALSE                 FALSE          FALSE
#
#    Nuclear dependent Gas dependent Increased exports At least 10% trade  \
# 1               TRUE          TRUE              TRUE               TRUE
# 2               TRUE          TRUE              TRUE               TRUE
# 3              FALSE          TRUE              TRUE               TRUE
# 4               TRUE         FALSE              TRUE              FALSE
# 5              FALSE         FALSE             FALSE               TRUE
# 6              FALSE         FALSE              TRUE               TRUE
# 7              FALSE         FALSE             FALSE              FALSE
# 8               TRUE         FALSE              TRUE              FALSE
# 9              FALSE         FALSE              TRUE              FALSE
# 10             FALSE         FALSE             FALSE              FALSE
# 11              TRUE         FALSE             FALSE              FALSE
# 12              TRUE         FALSE              TRUE               TRUE
#
#    Unnamed: 12
# 1           11
# 2            9
# 3            8
# 4            6
# 5            6
# 6            6
# 7            5
# 8            5
# 9            5
# 10           4
# 11           4
# 12           4

# %%
column_name = 'Unnamed: 5'  # Replace 'column_name' with the actual column name you want to drop

# Drop the column
df = df.drop(column_name, axis=1)

# %%
df
# Out:
#      Countries Not vote against Russia Voted for Russia Arms Supplier  \
# 1      Belarus                    TRUE             TRUE          TRUE
# 2      Armenia                    TRUE            FALSE         FALSE
# 3   Kyrgyzstan                    TRUE            FALSE         FALSE
# 4         Iran                    TRUE            FALSE          TRUE
# 5   Tajikistan                    TRUE            FALSE         FALSE
# 6   Kazakhstan                    TRUE            FALSE         FALSE
# 7       Syria                     TRUE             TRUE         FALSE
# 8        China                    TRUE            FALSE         FALSE
# 9    Venezuela                    TRUE            FALSE         FALSE
# 10   Nicaragua                    TRUE             TRUE         FALSE
# 11       India                    TRUE            FALSE         FALSE
# 12  Uzbekistan                    TRUE            FALSE         FALSE
#
#    CSTO member Joint military drills Arms dependent Nuclear dependent  \
# 1         TRUE                  TRUE           TRUE              TRUE
# 2         TRUE                  TRUE           TRUE              TRUE
# 3         TRUE                  TRUE           TRUE             FALSE
# 4        FALSE                  TRUE           TRUE              TRUE
# 5         TRUE                  TRUE           TRUE             FALSE
# 6         TRUE                  TRUE           TRUE             FALSE
# 7        FALSE                  TRUE           TRUE             FALSE
# 8        FALSE                  TRUE           TRUE              TRUE
# 9        FALSE                  TRUE           TRUE             FALSE
# 10       FALSE                  TRUE           TRUE             FALSE
# 11       FALSE                  TRUE           TRUE              TRUE
# 12       FALSE                 FALSE          FALSE              TRUE
#
#    Gas dependent Increased exports At least 10% trade Unnamed: 12
# 1           TRUE              TRUE               TRUE          11
# 2           TRUE              TRUE               TRUE           9
# 3           TRUE              TRUE               TRUE           8
# 4          FALSE              TRUE              FALSE           6
# 5          FALSE             FALSE               TRUE           6
# 6          FALSE              TRUE               TRUE           6
# 7          FALSE             FALSE              FALSE           5
# 8          FALSE              TRUE              FALSE           5
# 9          FALSE              TRUE              FALSE           5
# 10         FALSE             FALSE              FALSE           4
# 11         FALSE             FALSE              FALSE           4
# 12         FALSE              TRUE               TRUE           4

# %%
column_name = 'Unnamed: 12'  # Replace 'column_name' with the actual column name you want to drop

# Drop the column
df = df.drop(column_name, axis=1)

# %%
df
# Out:
#      Countries Not vote against Russia Voted for Russia Arms Supplier  \
# 1      Belarus                    TRUE             TRUE          TRUE
# 2      Armenia                    TRUE            FALSE         FALSE
# 3   Kyrgyzstan                    TRUE            FALSE         FALSE
# 4         Iran                    TRUE            FALSE          TRUE
# 5   Tajikistan                    TRUE            FALSE         FALSE
# 6   Kazakhstan                    TRUE            FALSE         FALSE
# 7       Syria                     TRUE             TRUE         FALSE
# 8        China                    TRUE            FALSE         FALSE
# 9    Venezuela                    TRUE            FALSE         FALSE
# 10   Nicaragua                    TRUE             TRUE         FALSE
# 11       India                    TRUE            FALSE         FALSE
# 12  Uzbekistan                    TRUE            FALSE         FALSE
#
#    CSTO member Joint military drills Arms dependent Nuclear dependent  \
# 1         TRUE                  TRUE           TRUE              TRUE
# 2         TRUE                  TRUE           TRUE              TRUE
# 3         TRUE                  TRUE           TRUE             FALSE
# 4        FALSE                  TRUE           TRUE              TRUE
# 5         TRUE                  TRUE           TRUE             FALSE
# 6         TRUE                  TRUE           TRUE             FALSE
# 7        FALSE                  TRUE           TRUE             FALSE
# 8        FALSE                  TRUE           TRUE              TRUE
# 9        FALSE                  TRUE           TRUE             FALSE
# 10       FALSE                  TRUE           TRUE             FALSE
# 11       FALSE                  TRUE           TRUE              TRUE
# 12       FALSE                 FALSE          FALSE              TRUE
#
#    Gas dependent Increased exports At least 10% trade
# 1           TRUE              TRUE               TRUE
# 2           TRUE              TRUE               TRUE
# 3           TRUE              TRUE               TRUE
# 4          FALSE              TRUE              FALSE
# 5          FALSE             FALSE               TRUE
# 6          FALSE              TRUE               TRUE
# 7          FALSE             FALSE              FALSE
# 8          FALSE              TRUE              FALSE
# 9          FALSE              TRUE              FALSE
# 10         FALSE             FALSE              FALSE
# 11         FALSE             FALSE              FALSE
# 12         FALSE              TRUE               TRUE

# %% [markdown]
# #### According the data, Iran and Belarus are Russia's allies which provide arms to the Moscow.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.scatter(df['Arms Supplier'], df['Countries'])

# %% [markdown]
# #### Three countries in the group of Putin's allies voted for Russia in the UN. Nicaragua, Syria and Belarus.

# %%
sns.set()
plt.scatter(df['Voted for Russia'], df['Countries'])

# %% [markdown]
# #### Eventhough, not all the allies of Russia voted for it, but non of them voted against it too.

# %%
sns.set()
plt.scatter(df['Not vote against Russia'], df['Countries'])

# %% [markdown]
# ##### The following bar chart shows randomly Putin's allies with three factors: At least 10% trade with Russia, Voted for Russia and Arms Supplier.
# #### This bar chart shows the correlation between these factors.

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=['At least 10% trade','Voted for Russia', 'Arms Supplier'])
df.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ##### As you can find in the bar chart and scatter plots, the countries that didn't vote against Russia and have trade with Moscow are not necessarily supporting the country in the international society.
#
# ##### The Economist emphasises that on the surface, Russia seems to have gained significant support in the past year. However, in reality, these alliances and friendships may not be as meaningful or substantial as they appear.
